# %% [markdown]
# # CS5100 - Conversational Agent Training Script
#
# Using Seq2Seq LSTM models

# %%
dataset_path = 'movie_dialog.json'
file_id_train = '18nVAPJJuwFWx3OymgE21m_BbVKfeIdeQ' # movie_dialog.json from Google Drive
dataset_name = 'CornellMovieDialog'
model_name = 'model' + dataset_name

# %% [markdown]
# ## 1. Importing Packages

# %%
import numpy as np
import tensorflow as tf
import pickle
from tensorflow.keras import layers , activations , models , preprocessing
from typing import Tuple, List

# %% [markdown]
# ## 2. Preprocessing Dataset
#
# **Cornell Movie--Dialogs Corpus**
#
# Distributed together with:  Chameleons in Imagined Conversations.
#
# Data and Code available in ConvoKit: a toolkit for analyzing conversations
#
# Related corpus: Cornell Movie-Quotes Corpus
#
# **DESCRIPTION:**
#
# This corpus contains a large metadata-rich collection of fictional conversations extracted from raw movie scripts:
#
# - 220,579 conversational exchanges between 10,292 pairs of movie characters
#
# - involves 9,035 characters from 617 movies
#
# - in total 304,713 utterances
#
# - movie metadata included:
#
#     - genres
#
#     - release year
#
#     - IMDB rating
#
#     - number of IMDB votes
#
#     - IMDB rating
#
# - character metadata included:
#
#     - gender (for 3,774 characters)
#
#     - position on movie credits (3,321 characters)
#
# - see the [documentation](https://convokit.cornell.edu/documentation/movie.html) for details

# %% [markdown]
# *    Read the JSON file

# %%
# Download and load the dataset
import json

# !gdown $file_id_train

with open(dataset_path, 'r') as file:
    data = json.load(file)

# Filter out responses that are over 100 characters long
data = [item for item in data if len(item['answer']) <= 100 and len(item['question']) <= 100]

# Using only a portion of the dataset
# Limit the size of the dataset if lack system RAM
data = data[:15000]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18nVAPJJuwFWx3OymgE21m_BbVKfeIdeQ
# To: /content/movie_dialog.json
# 100% 11.4M/11.4M [00:00<00:00, 64.0MB/s]

# %%
print(f"Sample 1: {data[0]}")
print(f"Sample 2: {data[1]}")
print(f"Sample 3: {data[2]}")
# Out:
# Sample 1: {'question': "You're asking me out.  That's so cute. What's your name again?", 'answer': 'Forget it.'}
# Sample 2: {'question': "No, no, it's my fault -- we didn't have a proper introduction ---", 'answer': 'Cameron.'}
# Sample 3: {'question': 'Gosh, if only we could find Kat a boyfriend...', 'answer': 'Let me see what I can do.'}

# %% [markdown]
# *    Remove unwanted data types which are produced while parsing the data.
# *    Append `<BOS>`, beginning-of-sentence token, and `<EOS>`, end-of-sentence token, to all the answers.
# *    Create a Tokenizer and load the whole vocabulary ( questions + answers ) into it.

# %%
from tensorflow.keras import preprocessing, utils

questions_list = []
answers_list = []

for item in data:
    question = item['question']
    answer = item['answer']

    questions_list.append(question)
    answers_list.append('<BOS> ' + answer + ' <EOS>')

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(['<UNK>'] + questions_list + answers_list)

vocab_size = len(tokenizer.word_index) + 1

# Save the tokenizer
with open(f'tokenizer{dataset_name}.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
print(f"Vocab size: {vocab_size}")
print(f"Vocab: {tokenizer.word_index}")
# Out:
# Vocab size: 12584
# Vocab: {'bos': 1, 'eos': 2, 'you': 3, 'i': 4, 'the': 5, 'to': 6, 'a': 7, 'it': 8, 'what': 9, 'is': 10, 'me': 11, 'that': 12, 'of': 13, 'in': 14, 'this': 15, 'do': 16, 'and': 17, "don't": 18, "i'm": 19, 'we': 20, 'are': 21, 'for': 22, 'have': 23, 'your': 24, 'my': 25, 'know': 26, "it's": 27, 'no': 28, 'not': 29, 'on': 30, 'he': 31, 'be': 32, 'here': 33, 'was': 34, 'just': 35, 'with': 36, 'like': 37, 'get': 38, "you're": 39, 'how': 40, 'all': 41, 'so': 42, 'out': 43, 'about': 44, 'go': 45, 'think': 46, 'want': 47, 'but': 48, 'him': 49, 'can': 50, 'got': 51, 'right': 52, 'up': 53, 'going': 54, "that's": 55, 'did': 56, 'oh': 57, 'there': 58, 'if': 59, 'now': 60, 'yes': 61, 'one': 62, 'why': 63, 'they': 64, 'at': 65, 'well': 66, 'yeah': 67, 'see': 68, 'where': 69, 'good': 70, "what's": 71, 'come': 72, 'us': 73, "he's": 74, "can't": 75, "i'll": 76, 'who': 77, 'her': 78, 'look': 79, 'been': 80, 'say': 81, 'time': 82, 'back': 83, 'she': 84, 'man': 85, 'will': 86, 'take': 87, 'some': 88, 'tell': 89, 'okay': 90, 'an': 91, "we're": 92, "didn't": 93, 'were': 94, 'them': 95, 'when': 96, 'from': 97, 'his': 98, 'sure': 99, 'as': 100, "i've": 101, 'hey': 102, 'would': 103, 'could': 104, 'something': 105, 'never': 106, 'need': 107, 'sorry': 108, 'really': 109, 'too': 110, 'or': 111, 'doing': 112, 'gonna': 113, 'down': 114, 'way': 115, 'mr': 116, 'let': 117, 'any': 118, 'had': 119, 'mean': 120, 'very': 121, 'make': 122, 'over': 123, 'little': 124, 'off': 125, 'much': 126, 'then': 127, 'please': 128, "let's": 129, 'more': 130, 'maybe': 131, 'said': 132, 'talk': 133, "there's": 134, 'our': 135, 'thing': 136, 'should': 137, 'am': 138, 'give': 139, 'god': 140, 'two': 141, 'thought': 142, 'nothing': 143, 'wait': 144, 'shit': 145, 'only': 146, 'anything': 147, 'thank': 148, 'hello': 149, 'help': 150, 'long': 151, 'call': 152, 'better': 153, 'has': 154, 'find': 155, 'last': 156, "she's": 157, "isn't": 158, 'must': 159, 'home': 160, 'thanks': 161, 'sir': 162, 'love': 163, 'told': 164, 'hell': 165, 'first': 166, "they're": 167, 'by': 168, 'before': 169, 'still': 170, 'night': 171, 'work': 172, 'nice': 173, "i'd": 174, "we'll": 175, 'fuck': 176, 'these': 177, 'happened': 178, 'name': 179, 'keep': 180, 'hi': 181, 'stop': 182, 'ever': 183, 'kill': 184, 'place': 185, 'again': 186, 'believe': 187, 'money': 188, "won't": 189, 'guy': 190, 'wrong': 191, 'ask': 192, 'uh': 193, "you've": 194, 'leave': 195, 'bad': 196, 'does': 197, 'people': 198, 'fine': 199, 'old': 200, 'big': 201, 'huh': 202, 'those': 203, 'great': 204, 'even': 205, 'stay': 206, 'remember': 207, 'always': 208, 'gotta': 209, 'day': 210, 'put': 211, 'feel': 212, 'into': 213, 'hear': 214, "ain't": 215, 'other': 216, 'dead': 217, "doesn't": 218, 'around': 219, 'course': 220, 'girl': 221, 'mind': 222, 'after': 223, 'getting': 224, 'another': 225, 'dad': 226, 'kind': 227, "you'll": 228, 'father': 229, 'than': 230, 'came': 231, 'new': 232, 'looking': 233, 'life': 234, 'things': 235, 'guys': 236, 'guess': 237, 'away': 238, "we've": 239, 'three': 240, 'try': 241, 'talking': 242, 'morning': 243, 'done': 244, 'tonight': 245, 'everything': 246, 'enough': 247, "where's": 248, 'friend': 249, 'coming': 250, 'ya': 251, 'five': 252, 'years': 253, 'left': 254, 'house': 255, 'listen': 256, 'made': 257, 'car': 258, 'because': 259, 'pretty': 260, 'may': 261, 'lot': 262, 'already': 263, 'looks': 264, 'seen': 265, 'mrs': 266, 'next': 267, 'else': 268, 'boy': 269, 'might': 270, "haven't": 271, 'baby': 272, 'tomorrow': 273, 'many': 274, 'jack': 275, "wasn't": 276, 'mom': 277, 'went': 278, 'room': 279, 'hold': 280, 'four': 281, "wouldn't": 282, 'minute': 283, 'understand': 284, 'real': 285, 'fucking': 286, 'matter': 287, 'late': 288, 'yourself': 289, 'son': 290, 'wanted': 291, 'heard': 292, 'move': 293, 'through': 294, 'yet': 295, 'john': 296, "who's": 297, 'ready': 298, 'idea': 299, 'shut': 300, 'head': 301, 'drink': 302, 'mother': 303, 'miss': 304, 'best': 305, 'jesus': 306, 'killed': 307, 'door': 308, 'knew': 309, 'sh ...

# %% [markdown]
# `encoder_input_data`: tokenize the list of questions. Pad them to their maximum length.
#
# `decoder_input_data`: tokenize the list of answers. Pad them to their maximum length.
#
# `decoder_output_data`: tokenize the list of answers. Remove the first element `<BOS>` from all the `tokenized_answers`.

# %%
from gensim.models import Word2Vec
import re

vocab = []
for word in tokenizer.word_index:
    vocab.append(word)

def tokenize(sentences: list) -> Tuple[List[List[str]], List[str]]:
    """
    Tokenize the sentences

    Parameters:
        sentences: list of sentences

    Returns:
        tokenized_sentences: list of tokenized sentences
        vocab_list: list of vocabulary
    """
    tokens_list = []
    vocab_list = [] # Include an unknown token for unknown words
    for sentence in sentences:
        sentence = sentence.lower() # Convert to lower case
        sentence = re.sub('[^a-zA-z0-9\']', ' ', sentence) # Remove special characters
        tokens = sentence.split() # Tokenize the sentence
        vocab_list.extend(tokens)
        tokens_list.append(tokens)

    return tokens_list, vocab_list

# encoder_input_data
tokenized_questions = tokenizer.texts_to_sequences(questions_list)
questions_max_len = max([ len(x) for x in tokenized_questions ])
padded_questions = preprocessing.sequence.pad_sequences(tokenized_questions, maxlen=questions_max_len, padding='post')
encoder_input_data = np.array(padded_questions)
print(f"Encoder input data shape: (# Samples, Max Sequence Length): {encoder_input_data.shape}")

# decoder_input_data
tokenized_answers = tokenizer.texts_to_sequences(answers_list)
answers_max_len = max([ len(x) for x in tokenized_answers ])
padded_answers = preprocessing.sequence.pad_sequences(tokenized_answers, maxlen=answers_max_len, padding='post')
decoder_input_data = np.array(padded_answers)
print(f"Decoder input data shape: (# Samples, Max Sequence Length): {decoder_input_data.shape}")

# decoder_output_data
tokenized_answers = tokenizer.texts_to_sequences(answers_list)
for i in range(len(tokenized_answers)):
    tokenized_answers[i] = tokenized_answers[i][1:] # Remove the <bos> token

padded_answers = preprocessing.sequence.pad_sequences(tokenized_answers, maxlen=answers_max_len, padding='post')
onehot_answers = utils.to_categorical(padded_answers, vocab_size)
decoder_output_data = np.array(onehot_answers)
print(f"Decoder output data shape: (# Samples, Max Sequence Length, Vocab Size): {decoder_output_data.shape}")
# Out:
# Encoder input data shape: (# Samples, Max Sequence Length): (15000, 23)
# Decoder input data shape: (# Samples, Max Sequence Length): (15000, 27)
# Decoder output data shape: (# Samples, Max Sequence Length, Vocab Size): (15000, 27, 12584)

# %% [markdown]
# The model will have Embedding, LSTM and Dense layers. The basic configuration is as follows.
#
#
# *    2 Input Layers : One for `encoder_input_data` and another for `decoder_input_data`.
# *    Embedding layer : For converting token vectors to fix sized dense vectors. **( Note :  Don't forget the `mask_zero=True` argument here )**
# *    LSTM layer : Provide access to Long-Short Term cells.
#
# Working :
#
# 1.    The `encoder_input_data` comes in the Embedding layer (  `encoder_embedding` ).
# 2.    The output of the Embedding layer goes to the LSTM cell which produces 2 state vectors ( `h` and `c` which are `encoder_states` )
# 3.    These states are set in the LSTM cell of the decoder.
# 4.    The decoder_input_data comes in through the Embedding layer.
# 5.    The Embeddings goes in LSTM cell ( which had the states ) to produce seqeunces.

# %%
encoder_inputs = tf.keras.layers.Input(shape=(questions_max_len,), name='Encoder_Inputs')
encoder_embedding = tf.keras.layers.Embedding(vocab_size, 200, mask_zero=True, name='Encoder_Embedding')(encoder_inputs)
encoder_ouputs, state_h, state_c = tf.keras.layers.LSTM(200, return_state=True, name='Encoder_LSTM')(encoder_embedding)
encoder_states = [state_h, state_c]

decoder_inputs = tf.keras.layers.Input(shape=(answers_max_len,), name='Decoder_Inputs')
decoder_embedding = tf.keras.layers.Embedding(vocab_size, 200, mask_zero=True, name='Decoder_Embedding')(decoder_inputs)
decoder_lstm = tf.keras.layers.LSTM(200, return_state=True, return_sequences=True, name='Decoder_LSTM')
decoder_ouputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)

decoder_dense = tf.keras.layers.Dense(vocab_size, activation=tf.keras.activations.softmax, name='Output_Layer')
output = decoder_dense(decoder_ouputs)

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output, name='Encoder_Decoder_Model')
model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='categorical_crossentropy')

model.summary()
# Out:
# Model: "Encoder_Decoder_Model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Encoder_Inputs (InputLayer  [(None, 23)]                 0         []
#  )
#
#  Decoder_Inputs (InputLayer  [(None, 27)]                 0         []
#  )
#
#  Encoder_Embedding (Embeddi  (None, 23, 200)              2516800   ['Encoder_Inputs[0][0]']
#  ng)
#
#  Decoder_Embedding (Embeddi  (None, 27, 200)              2516800   ['Decoder_Inputs[0][0]']
#  ng)
#
#  Encoder_LSTM (LSTM)         [(None, 200),                320800    ['Encoder_Embedding[0][0]']
#                               (None, 200),
#                               (None, 200)]
#
#  Decoder_LSTM (LSTM)         [(None, 27, 200),            320800    ['Decoder_Embedding[0][0]',
#                               (None, 200),                           'Encoder_LSTM[0][1]',
#                               (None, 200)]                           'Encoder_LSTM[0][2]']
#
#  Output_Layer (Dense)        (None, 27, 12584)            2529384   ['Decoder_LSTM[0][0]']
#
# ==================================================================================================
# Total params: 8204584 (31.30 MB)
# Trainable params: 8204584 (31.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3. Training Model
#
# Train the model for a number of epochs with `RMSprop` optimizer and `categorical_crossentropy` loss function.

# %%
model.fit([encoder_input_data , decoder_input_data], decoder_output_data, batch_size=50, epochs=600 )
model.save(f"{model_name}.keras")
# Out:
# Epoch 1/600
# 300/300 [==============================] - 27s 68ms/step - loss: 6.0631
# Epoch 2/600
# 300/300 [==============================] - 10s 35ms/step - loss: 5.4968
# Epoch 3/600
# 300/300 [==============================] - 10s 34ms/step - loss: 5.3040
# Epoch 4/600
# 300/300 [==============================] - 10s 32ms/step - loss: 5.2306
# Epoch 5/600
# 300/300 [==============================] - 9s 31ms/step - loss: 5.1664
# Epoch 6/600
# 300/300 [==============================] - 10s 32ms/step - loss: 5.0990
# Epoch 7/600
# 300/300 [==============================] - 10s 32ms/step - loss: 5.0309
# Epoch 8/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.9735
# Epoch 9/600
# 300/300 [==============================] - 9s 32ms/step - loss: 4.9264
# Epoch 10/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.8857
# Epoch 11/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.8468
# Epoch 12/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.8141
# Epoch 13/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.7816
# Epoch 14/600
# 300/300 [==============================] - 9s 30ms/step - loss: 4.7538
# Epoch 15/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.7252
# Epoch 16/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.7004
# Epoch 17/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.6765
# Epoch 18/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.6527
# Epoch 19/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.6316
# Epoch 20/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.6118
# Epoch 21/600
# 300/300 [==============================] - 9s 32ms/step - loss: 4.5944
# Epoch 22/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.5749
# Epoch 23/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.5580
# Epoch 24/600
# 300/300 [==============================] - 9s 30ms/step - loss: 4.5414
# Epoch 25/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.5258
# Epoch 26/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.5115
# Epoch 27/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.4964
# Epoch 28/600
# 300/300 [==============================] - 9s 30ms/step - loss: 4.4829
# Epoch 29/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.4676
# Epoch 30/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.4548
# Epoch 31/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.4428
# Epoch 32/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.4314
# Epoch 33/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.4187
# Epoch 34/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.4083
# Epoch 35/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.3959
# Epoch 36/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.3836
# Epoch 37/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.3718
# Epoch 38/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.3594
# Epoch 39/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.3483
# Epoch 40/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.3352
# Epoch 41/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.3258
# Epoch 42/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.3143
# Epoch 43/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.3017
# Epoch 44/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.2900
# Epoch 45/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.2774
# Epoch 46/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.2675
# Epoch 47/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.2538
# Epoch 48/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.2417
# Epoch 49/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.2310
# Epoch 50/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.2194
# Epoch 51/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.2082
# Epoch 52/600
# 300/300 [==============================] - 9s 30ms/step - loss: 4.1960
# Epoch 53/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.1851
# Epoch 54/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.1724
# Epoch 55/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.1599
# Epoch 56/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.1493
# Epoch 57/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.1360
# Epoch 58/600
# 300/300 [==============================] - 9s 30ms/step - loss: 4.1254
# Epoch 59/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.1138
# Epoch 60/600
# 300/300 [==============================] - 9s 30ms/step - loss: 4.0987
# Epoch 61/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.0886
# Epoch 62/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.0752
# Epoch 63/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.0641
# Epoch 64/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.0524
# Epoch 65/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.0380
# Epoch 66/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.0262
# Epoch 67/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.0132
# Epoch 68/600
# 300/300 [==============================] - 9s 31ms/step - loss: 4.0010
# Epoch 69/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.9888
# Epoch 70/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.9745
# Epoch 71/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.9621
# Epoch 72/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.9485
# Epoch 73/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.9344
# Epoch 74/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.9198
# Epoch 75/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.9050
# Epoch 76/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.8921
# Epoch 77/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.8795
# Epoch 78/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.8636
# Epoch 79/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.8482
# Epoch 80/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.8347
# Epoch 81/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.8187
# Epoch 82/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.8028
# Epoch 83/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.7857
# Epoch 84/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.7707
# Epoch 85/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.7545
# Epoch 86/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.7390
# Epoch 87/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.7222
# Epoch 88/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.7052
# Epoch 89/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.6886
# Epoch 90/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.6731
# Epoch 91/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.6564
# Epoch 92/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.6415
# Epoch 93/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.6219
# Epoch 94/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.6058
# Epoch 95/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.5902
# Epoch 96/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.5714
# Epoch 97/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.5557
# Epoch 98/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.5388
# Epoch 99/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.5229
# Epoch 100/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.5061
# Epoch 101/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.4893
# Epoch 102/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.4721
# Epoch 103/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.4546
# Epoch 104/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.4397
# Epoch 105/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.4234
# Epoch 106/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.4054
# Epoch 107/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.3885
# Epoch 108/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.3726
# Epoch 109/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.3557
# Epoch 110/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.3388
# Epoch 111/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.3231
# Epoch 112/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.3064
# Epoch 113/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.2901
# Epoch 114/600
# 300/300 [==============================] - 9s 30ms/step - loss: 3.2707
# Epoch 115/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.2553
# Epoch 116/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.2384
# Epoch 117/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.2207
# Epoch 118/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.2018
# Epoch 119/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.1855
# Epoch 120/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.1690
# Epoch 121/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.1516
# Epoch 122/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.1343
# Epoch 123/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.1163
# Epoch 124/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.1002
# Epoch 125/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.0831
# Epoch 126/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.0641
# Epoch 127/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.0454
# Epoch 128/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.0276
# Epoch 129/600
# 300/300 [==============================] - 9s 31ms/step - loss: 3.0106
# Epoch 130/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.9918
# Epoch 131/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.9746
# Epoch 132/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.9574
# Epoch 133/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.9377
# Epoch 134/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.9197
# Epoch 135/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.9013
# Epoch 136/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.8819
# Epoch 137/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.8637
# Epoch 138/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.8466
# Epoch 139/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.8270
# Epoch 140/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.8070
# Epoch 141/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.7881
# Epoch 142/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.7682
# Epoch 143/600
# 300/300 [==============================] - 9s 30ms/step - loss: 2.7482
# Epoch 144/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.7305
# Epoch 145/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.7111
# Epoch 146/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.6911
# Epoch 147/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.6715
# Epoch 148/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.6515
# Epoch 149/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.6318
# Epoch 150/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.6106
# Epoch 151/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.5926
# Epoch 152/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.5719
# Epoch 153/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.5512
# Epoch 154/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.5310
# Epoch 155/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.5139
# Epoch 156/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.4912
# Epoch 157/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.4734
# Epoch 158/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.4528
# Epoch 159/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.4334
# Epoch 160/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.4117
# Epoch 161/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.3925
# Epoch 162/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.3744
# Epoch 163/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.3518
# Epoch 164/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.3330
# Epoch 165/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.3119
# Epoch 166/600
# 300/300 [==============================] - 9s 30ms/step - loss: 2.2920
# Epoch 167/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.2728
# Epoch 168/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.2521
# Epoch 169/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.2311
# Epoch 170/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.2136
# Epoch 171/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.1947
# Epoch 172/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.1722
# Epoch 173/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.1517
# Epoch 174/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.1333
# Epoch 175/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.1145
# Epoch 176/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.0956
# Epoch 177/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.0748
# Epoch 178/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.0559
# Epoch 179/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.0391
# Epoch 180/600
# 300/300 [==============================] - 9s 31ms/step - loss: 2.0186
# Epoch 181/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.9997
# Epoch 182/600
# 300/300 [==============================] - 9s 30ms/step - loss: 1.9797
# Epoch 183/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.9618
# Epoch 184/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.9427
# Epoch 185/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.9230
# Epoch 186/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.9052
# Epoch 187/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.8879
# Epoch 188/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.8688
# Epoch 189/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.8510
# Epoch 190/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.8321
# Epoch 191/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.8132
# Epoch 192/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.7971
# Epoch 193/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.7778
# Epoch 194/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.7594
# Epoch 195/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.7427
# Epoch 196/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.7256
# Epoch 197/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.7092
# Epoch 198/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.6909
# Epoch 199/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.6759
# Epoch 200/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.6574
# Epoch 201/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.6419
# Epoch 202/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.6253
# Epoch 203/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.6096
# Epoch 204/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.5931
# Epoch 205/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.5761
# Epoch 206/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.5596
# Epoch 207/600
# 300/300 [==============================] - 9s 30ms/step - loss: 1.5438
# Epoch 208/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.5293
# Epoch 209/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.5134
# Epoch 210/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.4984
# Epoch 211/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.4840
# Epoch 212/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.4689
# Epoch 213/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.4532
# Epoch 214/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.4382
# Epoch 215/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.4240
# Epoch 216/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.4105
# Epoch 217/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.3952
# Epoch 218/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.3822
# Epoch 219/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.3666
# Epoch 220/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.3555
# Epoch 221/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.3400
# Epoch 222/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.3262
# Epoch 223/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.3138
# Epoch 224/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.3011
# Epoch 225/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.2894
# Epoch 226/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.2752
# Epoch 227/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.2619
# Epoch 228/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.2502
# Epoch 229/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.2394
# Epoch 230/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.2243
# Epoch 231/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.2127
# Epoch 232/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.2026
# Epoch 233/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.1884
# Epoch 234/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.1793
# Epoch 235/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.1655
# Epoch 236/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.1540
# Epoch 237/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.1440
# Epoch 238/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.1330
# Epoch 239/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.1223
# Epoch 240/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.1122
# Epoch 241/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.1005
# Epoch 242/600
# 300/300 [==============================] - 9s 30ms/step - loss: 1.0906
# Epoch 243/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.0816
# Epoch 244/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.0699
# Epoch 245/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.0604
# Epoch 246/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.0494
# Epoch 247/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.0398
# Epoch 248/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.0290
# Epoch 249/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.0186
# Epoch 250/600
# 300/300 [==============================] - 9s 31ms/step - loss: 1.0103
# Epoch 251/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9997
# Epoch 252/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9904
# Epoch 253/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9802
# Epoch 254/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9708
# Epoch 255/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.9624
# Epoch 256/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9535
# Epoch 257/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9448
# Epoch 258/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9358
# Epoch 259/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9287
# Epoch 260/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9183
# Epoch 261/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9106
# Epoch 262/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.9021
# Epoch 263/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8930
# Epoch 264/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8851
# Epoch 265/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8779
# Epoch 266/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8705
# Epoch 267/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8602
# Epoch 268/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8526
# Epoch 269/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8452
# Epoch 270/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8377
# Epoch 271/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.8281
# Epoch 272/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8237
# Epoch 273/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8169
# Epoch 274/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8089
# Epoch 275/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.8022
# Epoch 276/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7933
# Epoch 277/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7873
# Epoch 278/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7795
# Epoch 279/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7729
# Epoch 280/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7654
# Epoch 281/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7583
# Epoch 282/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7524
# Epoch 283/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7465
# Epoch 284/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7395
# Epoch 285/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7314
# Epoch 286/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7264
# Epoch 287/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7188
# Epoch 288/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7158
# Epoch 289/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7080
# Epoch 290/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.7024
# Epoch 291/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6963
# Epoch 292/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6905
# Epoch 293/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6829
# Epoch 294/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6784
# Epoch 295/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6699
# Epoch 296/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6664
# Epoch 297/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6604
# Epoch 298/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6535
# Epoch 299/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6488
# Epoch 300/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6426
# Epoch 301/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6381
# Epoch 302/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6328
# Epoch 303/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6290
# Epoch 304/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6228
# Epoch 305/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6159
# Epoch 306/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.6113
# Epoch 307/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6062
# Epoch 308/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.6003
# Epoch 309/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5961
# Epoch 310/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5918
# Epoch 311/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5855
# Epoch 312/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5814
# Epoch 313/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5752
# Epoch 314/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5708
# Epoch 315/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5682
# Epoch 316/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5630
# Epoch 317/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5582
# Epoch 318/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5540
# Epoch 319/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5483
# Epoch 320/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5452
# Epoch 321/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5407
# Epoch 322/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5364
# Epoch 323/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5308
# Epoch 324/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5274
# Epoch 325/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5223
# Epoch 326/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5192
# Epoch 327/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5144
# Epoch 328/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5098
# Epoch 329/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5076
# Epoch 330/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.5026
# Epoch 331/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4992
# Epoch 332/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4936
# Epoch 333/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4910
# Epoch 334/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4869
# Epoch 335/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4836
# Epoch 336/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4800
# Epoch 337/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4772
# Epoch 338/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4728
# Epoch 339/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4678
# Epoch 340/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.4644
# Epoch 341/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4613
# Epoch 342/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4554
# Epoch 343/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.4544
# Epoch 344/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.4505
# Epoch 345/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.4475
# Epoch 346/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4429
# Epoch 347/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4408
# Epoch 348/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.4355
# Epoch 349/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.4327
# Epoch 350/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.4297
# Epoch 351/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4259
# Epoch 352/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4219
# Epoch 353/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4207
# Epoch 354/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4161
# Epoch 355/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4142
# Epoch 356/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4104
# Epoch 357/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4083
# Epoch 358/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4032
# Epoch 359/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.4014
# Epoch 360/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3984
# Epoch 361/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3968
# Epoch 362/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3940
# Epoch 363/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3900
# Epoch 364/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3849
# Epoch 365/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3832
# Epoch 366/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3809
# Epoch 367/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3775
# Epoch 368/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3762
# Epoch 369/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3729
# Epoch 370/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.3709
# Epoch 371/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3681
# Epoch 372/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3641
# Epoch 373/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3624
# Epoch 374/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3605
# Epoch 375/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3574
# Epoch 376/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3543
# Epoch 377/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3502
# Epoch 378/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3487
# Epoch 379/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3461
# Epoch 380/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3441
# Epoch 381/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3413
# Epoch 382/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3391
# Epoch 383/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3368
# Epoch 384/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3339
# Epoch 385/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3327
# Epoch 386/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3287
# Epoch 387/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3268
# Epoch 388/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3254
# Epoch 389/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3230
# Epoch 390/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3208
# Epoch 391/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3191
# Epoch 392/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3158
# Epoch 393/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3128
# Epoch 394/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3114
# Epoch 395/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3092
# Epoch 396/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3068
# Epoch 397/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3057
# Epoch 398/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3036
# Epoch 399/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.3024
# Epoch 400/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2992
# Epoch 401/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2986
# Epoch 402/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2963
# Epoch 403/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2934
# Epoch 404/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.2912
# Epoch 405/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2891
# Epoch 406/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2869
# Epoch 407/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2839
# Epoch 408/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2834
# Epoch 409/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2797
# Epoch 410/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2788
# Epoch 411/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2773
# Epoch 412/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2749
# Epoch 413/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.2721
# Epoch 414/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2716
# Epoch 415/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2698
# Epoch 416/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2682
# Epoch 417/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2657
# Epoch 418/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2647
# Epoch 419/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2629
# Epoch 420/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2604
# Epoch 421/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2598
# Epoch 422/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2572
# Epoch 423/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2562
# Epoch 424/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2541
# Epoch 425/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2520
# Epoch 426/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2517
# Epoch 427/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2492
# Epoch 428/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2468
# Epoch 429/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2458
# Epoch 430/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2449
# Epoch 431/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2440
# Epoch 432/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2411
# Epoch 433/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2384
# Epoch 434/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2377
# Epoch 435/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2372
# Epoch 436/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2352
# Epoch 437/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2336
# Epoch 438/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2328
# Epoch 439/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2305
# Epoch 440/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2297
# Epoch 441/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2274
# Epoch 442/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2261
# Epoch 443/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2257
# Epoch 444/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2235
# Epoch 445/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2216
# Epoch 446/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2210
# Epoch 447/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2189
# Epoch 448/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2178
# Epoch 449/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2172
# Epoch 450/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2158
# Epoch 451/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2144
# Epoch 452/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2127
# Epoch 453/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2118
# Epoch 454/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2113
# Epoch 455/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.2110
# Epoch 456/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2083
# Epoch 457/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2065
# Epoch 458/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2051
# Epoch 459/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2040
# Epoch 460/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2026
# Epoch 461/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2006
# Epoch 462/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.2003
# Epoch 463/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1985
# Epoch 464/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1966
# Epoch 465/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1966
# Epoch 466/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1958
# Epoch 467/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1947
# Epoch 468/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1931
# Epoch 469/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1931
# Epoch 470/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1909
# Epoch 471/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1907
# Epoch 472/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1883
# Epoch 473/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1875
# Epoch 474/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1873
# Epoch 475/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1847
# Epoch 476/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1833
# Epoch 477/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1823
# Epoch 478/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1813
# Epoch 479/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1804
# Epoch 480/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1794
# Epoch 481/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1795
# Epoch 482/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1783
# Epoch 483/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1771
# Epoch 484/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1758
# Epoch 485/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1748
# Epoch 486/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1730
# Epoch 487/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1742
# Epoch 488/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1723
# Epoch 489/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1702
# Epoch 490/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1701
# Epoch 491/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1683
# Epoch 492/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1676
# Epoch 493/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1679
# Epoch 494/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1668
# Epoch 495/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1665
# Epoch 496/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1645
# Epoch 497/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1642
# Epoch 498/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1628
# Epoch 499/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1623
# Epoch 500/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1619
# Epoch 501/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1610
# Epoch 502/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1592
# Epoch 503/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1589
# Epoch 504/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1584
# Epoch 505/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1574
# Epoch 506/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1554
# Epoch 507/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1549
# Epoch 508/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1538
# Epoch 509/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1519
# Epoch 510/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1521
# Epoch 511/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1521
# Epoch 512/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1518
# Epoch 513/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1506
# Epoch 514/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1503
# Epoch 515/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1508
# Epoch 516/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1476
# Epoch 517/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1479
# Epoch 518/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1476
# Epoch 519/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1464
# Epoch 520/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1454
# Epoch 521/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1444
# Epoch 522/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1436
# Epoch 523/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1431
# Epoch 524/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1403
# Epoch 525/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1411
# Epoch 526/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1402
# Epoch 527/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1406
# Epoch 528/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1388
# Epoch 529/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1384
# Epoch 530/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1378
# Epoch 531/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1380
# Epoch 532/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1366
# Epoch 533/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1356
# Epoch 534/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1356
# Epoch 535/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1354
# Epoch 536/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1332
# Epoch 537/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1343
# Epoch 538/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1332
# Epoch 539/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1313
# Epoch 540/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1311
# Epoch 541/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1314
# Epoch 542/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1311
# Epoch 543/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1316
# Epoch 544/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1296
# Epoch 545/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1292
# Epoch 546/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1286
# Epoch 547/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1269
# Epoch 548/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1266
# Epoch 549/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1252
# Epoch 550/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1262
# Epoch 551/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1265
# Epoch 552/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1258
# Epoch 553/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1238
# Epoch 554/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1236
# Epoch 555/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1230
# Epoch 556/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1242
# Epoch 557/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1229
# Epoch 558/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1230
# Epoch 559/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1212
# Epoch 560/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1214
# Epoch 561/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1196
# Epoch 562/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1183
# Epoch 563/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1180
# Epoch 564/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1175
# Epoch 565/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1169
# Epoch 566/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1191
# Epoch 567/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.1169
# Epoch 568/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1165
# Epoch 569/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1156
# Epoch 570/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1147
# Epoch 571/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.1149
# Epoch 572/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1142
# Epoch 573/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1132
# Epoch 574/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.1132
# Epoch 575/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1127
# Epoch 576/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1122
# Epoch 577/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1121
# Epoch 578/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1116
# Epoch 579/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1105
# Epoch 580/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1125
# Epoch 581/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1103
# Epoch 582/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1093
# Epoch 583/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1094
# Epoch 584/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1094
# Epoch 585/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1099
# Epoch 586/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1080
# Epoch 587/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1069
# Epoch 588/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1074
# Epoch 589/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1078
# Epoch 590/600
# 300/300 [==============================] - 9s 30ms/step - loss: 0.1073
# Epoch 591/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1072
# Epoch 592/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1060
# Epoch 593/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1060
# Epoch 594/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1052
# Epoch 595/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1056
# Epoch 596/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1043
# Epoch 597/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1021
# Epoch 598/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1018
# Epoch 599/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1018
# Epoch 600/600
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1011

# %% [markdown]
# ## 4. Define Inference Models
#
# **Encoder inference model**: Takes the question as input and outputs LSTM states ( `h` and `c` ).
#
# **Decoder inference model**: Takes in 2 inputs, one are the LSTM states ( Output of encoder model ), second are the answer input seqeunces ( ones not having the `<bos>` tag ). It will output the answers for the question which we fed to the encoder model and its state values.

# %%
def make_inference() -> Tuple[tf.keras.models.Model, tf.keras.models.Model]:
    """
    Constructs separate encoder and decoder models for inference based on a trained Encoder-Decoder model.

    Returns:
        encoder_model (tf.keras.models.Model): A Keras model representing the encoder component for inference.
            This model takes encoder inputs (sequences of tokens) and outputs the encoder states (hidden state
            and cell state) produced by the encoder LSTM layer.

        decoder_model (tf.keras.models.Model): A Keras model representing the decoder component for inference.
            This model takes decoder inputs (sequences of tokens) along with the initial decoder states (hidden
            state and cell state) as inputs and outputs the decoder outputs and updated decoder states.
            It consists of the decoder LSTM layer and the decoder dense layer.
    """
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)

    decoder_state_input_h = tf.keras.layers.Input(shape=(200,), name='Input_Layer_h')
    decoder_state_input_c = tf.keras.layers.Input(shape=(200,), name='Input_Layer_c')
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    decoder_outs, state_h, state_c = decoder_lstm(decoder_embedding, initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_ouputs = decoder_dense(decoder_outs)
    decoder_model = tf.keras.models.Model([decoder_inputs] + decoder_states_inputs, [decoder_ouputs] + decoder_states)

    return encoder_model, decoder_model

# %% [markdown]
# ## 5. Talking with Chatbot

# %% [markdown]
# Convert `str` into tokens with paddings.

# %%
def str_to_tokens(sentence: str) -> List[int]:
    words = sentence.lower()
    words = re.sub('[^a-zA-Z0-9\']', ' ', words)
    words = words.split()
    # tokens_list = [ tokenizer.word_index[word] for word in words ]
    tokens_list = list()
    for word in words:
        if word in tokenizer.word_index:
            tokens_list.append(tokenizer.word_index[word])
        else:
            tokens_list.append(tokenizer.word_index['unk'])
    padded_sequence = preprocessing.sequence.pad_sequences([tokens_list], maxlen=questions_max_len, padding='post')
    return padded_sequence

# %% [markdown]
# 1.    First, we take a question as input and predict the state values using `encoder_model`.
# 2.    We set the state values in the decoder's LSTM.
# 3.    Then, we generate a sequence which contains the `<start>` element.
# 4.    We input this sequence in the `decoder_model`.
# 5.    We replace the `<bos>` element with the element which was predicted by the `decoder_model` and update the state values.
# 6.    We carry out the above steps iteratively till we hit the `<eos>` tag or the maximum answer length.

# %%
encoder_model, decoder_model = make_inference()

input_strs = [
    "What is your name?",
    "How are you feeling today?",
    "What is the weather like outside?",
    "Can you tell me a joke?",
    "How old are you?",
    "What is the capital of France?",
    "How do I bake a cake?",
    "What time is it?",
    "Who is the president of the United States?",
    "What is the meaning of life?"]

for input_str in input_strs:

    # Convert input string to tokens for the encoder
    states_values = encoder_model.predict(str_to_tokens(input_str), verbose=0)

    # Initialize target sequence with 'bos' (beginning of sentence) token
    empty_target_seq = np.zeros((1, 1))
    empty_target_seq[0, 0] = tokenizer.word_index['bos']

    # Initialize variables for translation and stop condition
    stop_condition = False
    decoded_translation = ''

    while not stop_condition:
        # Predict next word using the decoder model
        decoder_outputs, h, c = decoder_model.predict([empty_target_seq] + states_values, verbose=0)

        # Get index of the most probable word and fine the word corresponding to the index
        sampled_word_index = np.argmax(decoder_outputs[0, -1, :])
        sampled_word = None
        for word, index in tokenizer.word_index.items():
            if sampled_word_index == index:
                if word !="eos" and word !="unk":
                    decoded_translation += f" {word}"
                sampled_word = word

        if sampled_word == 'eos' or len(decoded_translation.split()) > answers_max_len:
            stop_condition = True

        # Update target sequence with sampled word index
        empty_target_seq = np.zeros((1, 1))
        empty_target_seq[0, 0] = sampled_word_index

        # Update states for the next iteration
        states_values = [h, c]

    # Print the decoded translation
    print(f"Question: {input_str}")
    print(f"Answer: {decoded_translation}\n")
# Out:
# Question: What is your name?
# Answer:  don't give her your name
#
# Question: How are you feeling today?
# Answer:  i feel much better thank you for asking and you
#
# Question: What is the weather like outside?
# Answer:  we took him
#
# Question: Can you tell me a joke?
# Answer:  no just can look at them now
#
# Question: How old are you?
# Answer:  that's not really a very proper question
#
# Question: What is the capital of France?
# Answer:  no mama it is not to be ashamed of
#
# Question: How do I bake a cake?
# Answer:  i am i don't know honey what the hell are you
#
# Question: What time is it?
# Answer:  it's time for you to stand where the hell i told you
#
# Question: Who is the president of the United States?
# Answer:  on on a buy he thing i have to go
#
# Question: What is the meaning of life?
# Answer:  victor laszlo in the world

# %% [markdown]
# ## 6. Downloading the Model and Tokenizer

# %%
# zip the files and download
import os
import shutil
from google.colab import files
from datetime import datetime

temp_dir = 'output'
files_to_include = [f'model{dataset_name}.keras', f'tokenizer{dataset_name}.pickle']

if not os.path.exists(temp_dir):
    os.makedirs(temp_dir)

try:
    for file in files_to_include:
        shutil.copy(file, temp_dir)
except Exception as e:
    print(f"Error copying files: {e}")

file_name = f"Model{dataset_name}_{datetime.now().strftime('%Y%m%d-%H%M%S')}"
shutil.make_archive(file_name, 'zip', 'output')
files.download(file_name + '.zip')
