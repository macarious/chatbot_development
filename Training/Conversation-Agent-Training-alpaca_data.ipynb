# %% [markdown]
# # CS5100 - Conversational Agent
#
# Using Seq2Seq LSTM models

# %%
dataset_path = 'train.json'
file_id_train = '1qYS0TsSsMkBFINWqOryt6BiHlqZtS6Qs' # train.json from Google Drive
dataset_name = 'alpaca_data'
model_name = 'model' + dataset_name

# %% [markdown]
# ## 1. Importing Packages

# %%
import numpy as np
import tensorflow as tf
import pickle
from tensorflow.keras import layers , activations , models , preprocessing
from typing import Tuple, List

# %% [markdown]
# ## 2. Preprocessing Dataset
#
# Stanford Alpaca: An Instruction-following LLaMA Model
# Rohan Taori and Ishaan Gulrajani and Tianyi Zhang and Yann Dubois and Xuechen Li and Carlos Guestrin and Percy Liang and Tatsunori B. Hashimoto
#
# Dataset: https://github.com/tatsu-lab/stanford_alpaca/blob/main/alpaca_data.json
#
# Year of Publication: 2023
#
# Overview
# The current Alpaca model is fine-tuned from a 7B LLaMA model on 52K instruction-following data generated by the techniques in the Self-Instruct paper, with some modifications that we discuss in the next section. In a preliminary human evaluation, we found that the Alpaca 7B model behaves similarly to the text-davinci-003 model on the Self-Instruct instruction-following evaluation suite.
#
# Alpaca is still under development, and there are many limitations that have to be addressed. Importantly, we have not yet fine-tuned the Alpaca model to be safe and harmless. We thus encourage users to be cautious when interacting with Alpaca, and to report any concerning behavior to help improve the safety and ethical considerations of the model.
#
# Our initial release contains the data generation procedure, dataset, and training recipe. We intend to release the model weights if we are given permission to do so by the creators of LLaMA. For now, we have chosen to host a live demo to help readers better understand the capabilities and limits of Alpaca, as well as a way to help us better evaluate Alpaca's performance on a broader audience.

# %% [markdown]
# *    Read the JSON file

# %%
# Download and load the dataset
import json

# !gdown $file_id_train

with open(dataset_path, 'r') as file:
    data = json.load(file)

# Using only a portion of the dataset
# Limit the size of the dataset if lack system RAM
# data = data[:5000]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qYS0TsSsMkBFINWqOryt6BiHlqZtS6Qs
# To: /content/train.json
# 100% 19.0M/19.0M [00:00<00:00, 78.3MB/s]

# %%
print(f"Sample 1: {data[0]}")
print(f"Sample 2: {data[1]}")
print(f"Sample 3: {data[2]}")
# Out:
# Sample 1: {'question': 'Give three tips for staying healthy.', 'answer': '1.Eat a balanced diet and make sure to include plenty of fruits and vegetables. \n2. Exercise regularly to keep your body active and strong. \n3. Get enough sleep and maintain a consistent sleep schedule.'}
# Sample 2: {'question': 'What are the three primary colors?', 'answer': 'The three primary colors are red, blue, and yellow.'}
# Sample 3: {'question': 'Describe the structure of an atom.', 'answer': 'An atom is made up of a nucleus, which contains protons and neutrons, surrounded by electrons that travel in orbits around the nucleus. The protons and neutrons have a positive charge, while the electrons have a negative charge, resulting in an overall neutral atom. The number of each particle determines the atomic number and the type of atom.'}

# %% [markdown]
# *    Remove unwanted data types which are produced while parsing the data.
# *    Append `<BOS>`, beginning-of-sentence token, and `<EOS>`, end-of-sentence token, to all the answers.
# *    Create a Tokenizer and load the whole vocabulary ( questions + answers ) into it.

# %%
from tensorflow.keras import preprocessing, utils
from tensorflow.keras.preprocessing.text import Tokenizer
from random import sample
max_sequence_length = 80

questions_list = []
answers_list = []

for item in data:
    question = item['question']
    answer = item['answer']
    # Temporarily tokenize question and answer to check length
    temp_question_tokens = question.split()  # Simple whitespace tokenization
    temp_answer_tokens = ('<BOS> ' + answer + ' <EOS>').split()

    # Only append if both question and answer are within the desired length
    if len(temp_question_tokens) <= max_sequence_length and len(temp_answer_tokens) <= max_sequence_length:
        questions_list.append(question)
        answers_list.append('<BOS> ' + answer + ' <EOS>')

# Calculate subset size (e.g., 10% of the data)
data_size = len(questions_list)
subset_size = int(0.1 * data_size)  # 10% of the total data

# Randomly select indices for the subset
indices = sample(range(data_size), subset_size)

# Create new lists containing only the sampled subset
sampled_questions_list = [questions_list[i] for i in indices]
sampled_answers_list = [answers_list[i] for i in indices]

tokenizer = Tokenizer()
tokenizer.fit_on_texts(['<UNK>'] + sampled_questions_list + sampled_answers_list)

vocab_size = len(tokenizer.word_index) + 1

# Save the tokenizer
with open(f'tokenizer{dataset_name}.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
print(f"Vocab size: {vocab_size}")
print(f"Vocab: {tokenizer.word_index}")
# Out:
# Vocab size: 13404
# Vocab: {'the': 1, 'a': 2, 'and': 3, 'of': 4, 'to': 5, 'bos': 6, 'eos': 7, 'in': 8, 'is': 9, 'for': 10, 'that': 11, 'with': 12, 'an': 13, 'it': 14, 'as': 15, 'are': 16, 'can': 17, 'be': 18, 'sentence': 19, 'following': 20, 'on': 21, 'given': 22, 'this': 23, 'or': 24, 'from': 25, 'by': 26, 'you': 27, '2': 28, '1': 29, '3': 30, 'what': 31, 'generate': 32, 'list': 33, '5': 34, 'i': 35, 'data': 36, 'create': 37, 'two': 38, 'used': 39, 'their': 40, 'have': 41, 'make': 42, '4': 43, 'was': 44, 'your': 45, 'new': 46, 'more': 47, 'such': 48, 'one': 49, 'using': 50, 'has': 51, 'how': 52, 'name': 53, 'about': 54, 'three': 55, 'also': 56, 'use': 57, 'into': 58, 'which': 59, 'words': 60, 'they': 61, 'should': 62, 'customer': 63, 'up': 64, 'describe': 65, 'identify': 66, 'find': 67, 'its': 68, 'example': 69, 'could': 70, 'write': 71, 'provide': 72, 'word': 73, 'will': 74, 'most': 75, 'he': 76, 'between': 77, 'include': 78, 'time': 79, 'if': 80, 'all': 81, 'learning': 82, 'when': 83, 'text': 84, 'language': 85, 'number': 86, 'other': 87, 'people': 88, 'help': 89, 'would': 90, 'explain': 91, 'at': 92, 'like': 93, 'energy': 94, 'five': 95, 'do': 96, 'way': 97, 'not': 98, '10': 99, 'ai': 100, 'we': 101, 'type': 102, 'while': 103, 'world': 104, 'different': 105, 'out': 106, 'our': 107, 'take': 108, 'them': 109, 'us': 110, 'system': 111, 'technology': 112, 'my': 113, 'product': 114, 'through': 115, 'she': 116, 'information': 117, 'main': 118, 'his': 119, 'additionally': 120, '8': 121, 'any': 122, 'who': 123, '6': 124, 'reduce': 125, 'so': 126, 'than': 127, 'based': 128, 'water': 129, 'each': 130, 'rewrite': 131, 'important': 132, 'tasks': 133, 'return': 134, 'making': 135, 'life': 136, 'input': 137, 'order': 138, 'over': 139, 'potential': 140, 'classify': 141, 'change': 142, 'items': 143, 'numbers': 144, '0': 145, 'best': 146, 'person': 147, 'natural': 148, 'me': 149, 'user': 150, 'service': 151, 'x': 152, 'these': 153, 'computer': 154, 'online': 155, 'but': 156, 'some': 157, 'statement': 158, 'set': 159, 'give': 160, 'output': 161, 'code': 162, 'machine': 163, 'work': 164, 'had': 165, 'well': 166, 'where': 167, 'model': 168, 'been': 169, 'better': 170, 'why': 171, 'related': 172, 'environment': 173, '7': 174, 'first': 175, 'both': 176, 'story': 177, 'problem': 178, 'calculate': 179, 'form': 180, 'movie': 181, 'day': 182, 'sentences': 183, 'design': 184, 'health': 185, 'b': 186, 'suggest': 187, 'come': 188, 'website': 189, 'get': 190, 'process': 191, 'food': 192, 'need': 193, 'improve': 194, 'article': 195, 'business': 196, 'experience': 197, 'her': 198, 'possible': 199, 'access': 200, 'social': 201, 'air': 202, 'correct': 203, 'city': 204, 'then': 205, 'positive': 206, 'states': 207, 'intelligence': 208, 'may': 209, 'climate': 210, 'phrase': 211, 'being': 212, 'store': 213, 'content': 214, 'software': 215, 'there': 216, 'c': 217, 'users': 218, 'good': 219, 'resources': 220, 'countries': 221, 'united': 222, 'go': 223, 'many': 224, 'artificial': 225, 'increase': 226, 'creating': 227, 'around': 228, 'were': 229, '9': 230, 'appropriate': 231, 'home': 232, 'meaning': 233, 'customers': 234, 'high': 235, 'creative': 236, 'same': 237, 'power': 238, 'increased': 239, 'edit': 240, 'no': 241, 'summarize': 242, 'features': 243, 'systems': 244, 'print': 245, 'add': 246, 'skills': 247, 'question': 248, 'function': 249, 'poem': 250, 'human': 251, 'sources': 252, 'learn': 253, 'area': 254, 'media': 255, 'able': 256, 'communication': 257, 'n': 258, 'research': 259, 'average': 260, 'right': 261, 'book': 262, 'program': 263, 'questions': 264, 'algorithm': 265, 'year': 266, 'products': 267, 'web': 268, 'made': 269, 'large': 270, 'marketing': 271, 'helps': 272, 'popular': 273, 'verb': 274, 'news': 275, 'value': 276, 'determine': 277, 'efficient': 278, 'because': 279, 'analyze': 280, 'sum': 281, 'title': 282, 'convert': 283, 'company': 284, 'develop': 285, 'construct': 286, 'common': 287, 'types': 288, 'family': 289, 'effective': 290, 'song': 291, 'global': 292, 'elem ...

# %% [markdown]
# `encoder_input_data`: tokenize the list of questions. Pad them to their maximum length.
#
# `decoder_input_data`: tokenize the list of answers. Pad them to their maximum length.
#
# `decoder_output_data`: tokenize the list of answers. Remove the first element `<BOS>` from all the `tokenized_answers`.

# %%
from gensim.models import Word2Vec
import re

vocab = []
for word in tokenizer.word_index:
    vocab.append(word)

def tokenize(sentences: list) -> Tuple[List[List[str]], List[str]]:
    """
    Tokenize the sentences

    Parameters:
        sentences: list of sentences

    Returns:
        tokenized_sentences: list of tokenized sentences
        vocab_list: list of vocabulary
    """
    tokens_list = []
    vocab_list = [] # Include an unknown token for unknown words
    for sentence in sentences:
        sentence = sentence.lower() # Convert to lower case
        sentence = re.sub('[^a-zA-z0-9\']', ' ', sentence) # Remove special characters
        tokens = sentence.split() # Tokenize the sentence
        vocab_list.extend(tokens)
        tokens_list.append(tokens)

    return tokens_list, vocab_list

# encoder_input_data
tokenized_questions = tokenizer.texts_to_sequences(sampled_questions_list)
questions_max_len = max([ len(x) for x in tokenized_questions ])
padded_questions = preprocessing.sequence.pad_sequences(tokenized_questions, maxlen=questions_max_len, padding='post')
encoder_input_data = np.array(padded_questions)
print(f"Encoder input data shape: (# Samples, Max Sequence Length): {encoder_input_data.shape}")

# decoder_input_data
tokenized_answers = tokenizer.texts_to_sequences(sampled_answers_list)
answers_max_len = max([ len(x) for x in tokenized_questions ])
padded_answers = preprocessing.sequence.pad_sequences(tokenized_answers, maxlen=answers_max_len, padding='post')
decoder_input_data = np.array(padded_answers)
print(f"Decoder input data shape: (# Samples, Max Sequence Length): {decoder_input_data.shape}")

# decoder_output_data
tokenized_answers = tokenizer.texts_to_sequences(sampled_answers_list)
for i in range(len(tokenized_answers)):
    tokenized_answers[i] = tokenized_answers[i][1:] # Remove the <bos> token

padded_answers = preprocessing.sequence.pad_sequences(tokenized_answers, maxlen=answers_max_len, padding='post')
onehot_answers = utils.to_categorical(padded_answers, vocab_size)
decoder_output_data = np.array(onehot_answers)
print(f"Decoder output data shape: (# Samples, Max Sequence Length, Vocab Size): {decoder_output_data.shape}")
# Out:
# Encoder input data shape: (# Samples, Max Sequence Length): (4209, 37)
# Decoder input data shape: (# Samples, Max Sequence Length): (4209, 37)
# Decoder output data shape: (# Samples, Max Sequence Length, Vocab Size): (4209, 37, 13404)

# %% [markdown]
# The model will have Embedding, LSTM and Dense layers. The basic configuration is as follows.
#
#
# *    2 Input Layers : One for `encoder_input_data` and another for `decoder_input_data`.
# *    Embedding layer : For converting token vectors to fix sized dense vectors. **( Note :  Don't forget the `mask_zero=True` argument here )**
# *    LSTM layer : Provide access to Long-Short Term cells.
#
# Working :
#
# 1.    The `encoder_input_data` comes in the Embedding layer (  `encoder_embedding` ).
# 2.    The output of the Embedding layer goes to the LSTM cell which produces 2 state vectors ( `h` and `c` which are `encoder_states` )
# 3.    These states are set in the LSTM cell of the decoder.
# 4.    The decoder_input_data comes in through the Embedding layer.
# 5.    The Embeddings goes in LSTM cell ( which had the states ) to produce seqeunces.

# %%
encoder_inputs = tf.keras.layers.Input(shape=(questions_max_len,), name='Encoder_Inputs')
encoder_embedding = tf.keras.layers.Embedding(vocab_size, 200, mask_zero=True, name='Encoder_Embedding')(encoder_inputs)
encoder_ouputs, state_h, state_c = tf.keras.layers.LSTM(200, return_state=True, name='Encoder_LSTM')(encoder_embedding)
encoder_states = [state_h, state_c]

decoder_inputs = tf.keras.layers.Input(shape=(answers_max_len,), name='Decoder_Inputs')
decoder_embedding = tf.keras.layers.Embedding(vocab_size, 200, mask_zero=True, name='Decoder_Embedding')(decoder_inputs)
decoder_lstm = tf.keras.layers.LSTM(200, return_state=True, return_sequences=True, name='Decoder_LSTM')
decoder_ouputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)

decoder_dense = tf.keras.layers.Dense(vocab_size, activation=tf.keras.activations.softmax, name='Output_Layer')
output = decoder_dense(decoder_ouputs)

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output, name='Encoder_Decoder_Model')
model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='categorical_crossentropy')

model.summary()
# Out:
# Model: "Encoder_Decoder_Model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Encoder_Inputs (InputLayer  [(None, 37)]                 0         []
#  )
#
#  Decoder_Inputs (InputLayer  [(None, 37)]                 0         []
#  )
#
#  Encoder_Embedding (Embeddi  (None, 37, 200)              2680800   ['Encoder_Inputs[0][0]']
#  ng)
#
#  Decoder_Embedding (Embeddi  (None, 37, 200)              2680800   ['Decoder_Inputs[0][0]']
#  ng)
#
#  Encoder_LSTM (LSTM)         [(None, 200),                320800    ['Encoder_Embedding[0][0]']
#                               (None, 200),
#                               (None, 200)]
#
#  Decoder_LSTM (LSTM)         [(None, 37, 200),            320800    ['Decoder_Embedding[0][0]',
#                               (None, 200),                           'Encoder_LSTM[0][1]',
#                               (None, 200)]                           'Encoder_LSTM[0][2]']
#
#  Output_Layer (Dense)        (None, 37, 13404)            2694204   ['Decoder_LSTM[0][0]']
#
# ==================================================================================================
# Total params: 8697404 (33.18 MB)
# Trainable params: 8697404 (33.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3. Training Model
#
# Train the model for a number of epochs with `RMSprop` optimizer and `categorical_crossentropy` loss function.

# %%
model.fit([encoder_input_data , decoder_input_data], decoder_output_data, batch_size=50, epochs=600 )
model.save(f"{model_name}.keras")
# Out:
# Epoch 1/600
# 85/85 [==============================] - 20s 134ms/step - loss: 7.8140
# Epoch 2/600
# 85/85 [==============================] - 8s 93ms/step - loss: 7.1187
# Epoch 3/600
# 85/85 [==============================] - 7s 87ms/step - loss: 7.0939
# Epoch 4/600
# 85/85 [==============================] - 6s 72ms/step - loss: 7.0782
# Epoch 5/600
# 85/85 [==============================] - 5s 63ms/step - loss: 7.0577
# Epoch 6/600
# 85/85 [==============================] - 5s 53ms/step - loss: 7.0127
# Epoch 7/600
# 85/85 [==============================] - 5s 57ms/step - loss: 6.8953
# Epoch 8/600
# 85/85 [==============================] - 4s 49ms/step - loss: 6.7967
# Epoch 9/600
# 85/85 [==============================] - 4s 52ms/step - loss: 6.7179
# Epoch 10/600
# 85/85 [==============================] - 4s 53ms/step - loss: 6.6502
# Epoch 11/600
# 85/85 [==============================] - 4s 52ms/step - loss: 6.5858
# Epoch 12/600
# 85/85 [==============================] - 4s 50ms/step - loss: 6.5146
# Epoch 13/600
# 85/85 [==============================] - 4s 46ms/step - loss: 6.4313
# Epoch 14/600
# 85/85 [==============================] - 4s 45ms/step - loss: 6.3537
# Epoch 15/600
# 85/85 [==============================] - 4s 46ms/step - loss: 6.2714
# Epoch 16/600
# 85/85 [==============================] - 4s 50ms/step - loss: 6.1824
# Epoch 17/600
# 85/85 [==============================] - 4s 48ms/step - loss: 6.0790
# Epoch 18/600
# 85/85 [==============================] - 4s 48ms/step - loss: 5.9870
# Epoch 19/600
# 85/85 [==============================] - 4s 46ms/step - loss: 5.9119
# Epoch 20/600
# 85/85 [==============================] - 4s 48ms/step - loss: 5.8439
# Epoch 21/600
# 85/85 [==============================] - 4s 45ms/step - loss: 5.7752
# Epoch 22/600
# 85/85 [==============================] - 4s 44ms/step - loss: 5.7115
# Epoch 23/600
# 85/85 [==============================] - 4s 44ms/step - loss: 5.6504
# Epoch 24/600
# 85/85 [==============================] - 4s 45ms/step - loss: 5.5944
# Epoch 25/600
# 85/85 [==============================] - 4s 47ms/step - loss: 5.5358
# Epoch 26/600
# 85/85 [==============================] - 4s 45ms/step - loss: 5.4826
# Epoch 27/600
# 85/85 [==============================] - 4s 46ms/step - loss: 5.4330
# Epoch 28/600
# 85/85 [==============================] - 4s 44ms/step - loss: 5.3832
# Epoch 29/600
# 85/85 [==============================] - 4s 46ms/step - loss: 5.3354
# Epoch 30/600
# 85/85 [==============================] - 4s 45ms/step - loss: 5.2855
# Epoch 31/600
# 85/85 [==============================] - 4s 46ms/step - loss: 5.2423
# Epoch 32/600
# 85/85 [==============================] - 4s 45ms/step - loss: 5.2007
# Epoch 33/600
# 85/85 [==============================] - 4s 44ms/step - loss: 5.1530
# Epoch 34/600
# 85/85 [==============================] - 4s 45ms/step - loss: 5.1096
# Epoch 35/600
# 85/85 [==============================] - 4s 44ms/step - loss: 5.0698
# Epoch 36/600
# 85/85 [==============================] - 4s 45ms/step - loss: 5.0254
# Epoch 37/600
# 85/85 [==============================] - 4s 42ms/step - loss: 4.9830
# Epoch 38/600
# 85/85 [==============================] - 4s 44ms/step - loss: 4.9397
# Epoch 39/600
# 85/85 [==============================] - 4s 44ms/step - loss: 4.9021
# Epoch 40/600
# 85/85 [==============================] - 4s 44ms/step - loss: 4.8601
# Epoch 41/600
# 85/85 [==============================] - 4s 43ms/step - loss: 4.8214
# Epoch 42/600
# 85/85 [==============================] - 4s 42ms/step - loss: 4.7804
# Epoch 43/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.7432
# Epoch 44/600
# 85/85 [==============================] - 4s 43ms/step - loss: 4.7090
# Epoch 45/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.6684
# Epoch 46/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.6305
# Epoch 47/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.6018
# Epoch 48/600
# 85/85 [==============================] - 4s 42ms/step - loss: 4.5619
# Epoch 49/600
# 85/85 [==============================] - 4s 46ms/step - loss: 4.5227
# Epoch 50/600
# 85/85 [==============================] - 4s 46ms/step - loss: 4.4931
# Epoch 51/600
# 85/85 [==============================] - 4s 46ms/step - loss: 4.4595
# Epoch 52/600
# 85/85 [==============================] - 4s 46ms/step - loss: 4.4257
# Epoch 53/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.3938
# Epoch 54/600
# 85/85 [==============================] - 4s 44ms/step - loss: 4.3600
# Epoch 55/600
# 85/85 [==============================] - 4s 42ms/step - loss: 4.3283
# Epoch 56/600
# 85/85 [==============================] - 4s 46ms/step - loss: 4.3007
# Epoch 57/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.2682
# Epoch 58/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.2373
# Epoch 59/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.2105
# Epoch 60/600
# 85/85 [==============================] - 4s 44ms/step - loss: 4.1836
# Epoch 61/600
# 85/85 [==============================] - 4s 42ms/step - loss: 4.1453
# Epoch 62/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.1183
# Epoch 63/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.0887
# Epoch 64/600
# 85/85 [==============================] - 4s 43ms/step - loss: 4.0624
# Epoch 65/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.0352
# Epoch 66/600
# 85/85 [==============================] - 4s 45ms/step - loss: 4.0069
# Epoch 67/600
# 85/85 [==============================] - 4s 45ms/step - loss: 3.9822
# Epoch 68/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.9535
# Epoch 69/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.9311
# Epoch 70/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.9043
# Epoch 71/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.8762
# Epoch 72/600
# 85/85 [==============================] - 4s 45ms/step - loss: 3.8485
# Epoch 73/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.8262
# Epoch 74/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.8025
# Epoch 75/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.7771
# Epoch 76/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.7543
# Epoch 77/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.7342
# Epoch 78/600
# 85/85 [==============================] - 4s 42ms/step - loss: 3.7109
# Epoch 79/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.6867
# Epoch 80/600
# 85/85 [==============================] - 4s 45ms/step - loss: 3.6613
# Epoch 81/600
# 85/85 [==============================] - 4s 42ms/step - loss: 3.6399
# Epoch 82/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.6180
# Epoch 83/600
# 85/85 [==============================] - 4s 46ms/step - loss: 3.5908
# Epoch 84/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.5715
# Epoch 85/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.5503
# Epoch 86/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.5260
# Epoch 87/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.5009
# Epoch 88/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.4794
# Epoch 89/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.4628
# Epoch 90/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.4415
# Epoch 91/600
# 85/85 [==============================] - 4s 45ms/step - loss: 3.4205
# Epoch 92/600
# 85/85 [==============================] - 4s 45ms/step - loss: 3.4000
# Epoch 93/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.3785
# Epoch 94/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.3546
# Epoch 95/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.3368
# Epoch 96/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.3210
# Epoch 97/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.2958
# Epoch 98/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.2821
# Epoch 99/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.2585
# Epoch 100/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.2366
# Epoch 101/600
# 85/85 [==============================] - 4s 45ms/step - loss: 3.2270
# Epoch 102/600
# 85/85 [==============================] - 4s 45ms/step - loss: 3.2079
# Epoch 103/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.1829
# Epoch 104/600
# 85/85 [==============================] - 4s 46ms/step - loss: 3.1665
# Epoch 105/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.1530
# Epoch 106/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.1297
# Epoch 107/600
# 85/85 [==============================] - 4s 43ms/step - loss: 3.1149
# Epoch 108/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.0932
# Epoch 109/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.0797
# Epoch 110/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.0669
# Epoch 111/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.0517
# Epoch 112/600
# 85/85 [==============================] - 4s 44ms/step - loss: 3.0280
# Epoch 113/600
# 85/85 [==============================] - 4s 45ms/step - loss: 3.0127
# Epoch 114/600
# 85/85 [==============================] - 4s 45ms/step - loss: 2.9984
# Epoch 115/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.9813
# Epoch 116/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.9643
# Epoch 117/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.9487
# Epoch 118/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.9284
# Epoch 119/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.9143
# Epoch 120/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.9009
# Epoch 121/600
# 85/85 [==============================] - 4s 45ms/step - loss: 2.8814
# Epoch 122/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.8677
# Epoch 123/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.8484
# Epoch 124/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.8400
# Epoch 125/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.8238
# Epoch 126/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.8062
# Epoch 127/600
# 85/85 [==============================] - 4s 45ms/step - loss: 2.7959
# Epoch 128/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.7781
# Epoch 129/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.7610
# Epoch 130/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.7469
# Epoch 131/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.7324
# Epoch 132/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.7194
# Epoch 133/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.7015
# Epoch 134/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.6912
# Epoch 135/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.6709
# Epoch 136/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.6658
# Epoch 137/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.6461
# Epoch 138/600
# 85/85 [==============================] - 4s 45ms/step - loss: 2.6406
# Epoch 139/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.6203
# Epoch 140/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.6077
# Epoch 141/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.5939
# Epoch 142/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.5840
# Epoch 143/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.5722
# Epoch 144/600
# 85/85 [==============================] - 4s 45ms/step - loss: 2.5556
# Epoch 145/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.5368
# Epoch 146/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.5206
# Epoch 147/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.5104
# Epoch 148/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.4962
# Epoch 149/600
# 85/85 [==============================] - 4s 45ms/step - loss: 2.4852
# Epoch 150/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.4721
# Epoch 151/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.4553
# Epoch 152/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.4469
# Epoch 153/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.4293
# Epoch 154/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.4260
# Epoch 155/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.4068
# Epoch 156/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.3929
# Epoch 157/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.3808
# Epoch 158/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.3696
# Epoch 159/600
# 85/85 [==============================] - 4s 45ms/step - loss: 2.3598
# Epoch 160/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.3459
# Epoch 161/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.3339
# Epoch 162/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.3186
# Epoch 163/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.3074
# Epoch 164/600
# 85/85 [==============================] - 4s 46ms/step - loss: 2.2992
# Epoch 165/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.2819
# Epoch 166/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.2725
# Epoch 167/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.2586
# Epoch 168/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.2470
# Epoch 169/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.2333
# Epoch 170/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.2193
# Epoch 171/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.2136
# Epoch 172/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.2031
# Epoch 173/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.1860
# Epoch 174/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.1726
# Epoch 175/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.1623
# Epoch 176/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.1497
# Epoch 177/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.1394
# Epoch 178/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.1256
# Epoch 179/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.1129
# Epoch 180/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.1056
# Epoch 181/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.0912
# Epoch 182/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.0786
# Epoch 183/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.0660
# Epoch 184/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.0574
# Epoch 185/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.0440
# Epoch 186/600
# 85/85 [==============================] - 4s 42ms/step - loss: 2.0305
# Epoch 187/600
# 85/85 [==============================] - 4s 44ms/step - loss: 2.0210
# Epoch 188/600
# 85/85 [==============================] - 4s 43ms/step - loss: 2.0131
# Epoch 189/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.9979
# Epoch 190/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.9847
# Epoch 191/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.9715
# Epoch 192/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.9625
# Epoch 193/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.9505
# Epoch 194/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.9387
# Epoch 195/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.9277
# Epoch 196/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.9182
# Epoch 197/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.9066
# Epoch 198/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.8941
# Epoch 199/600
# 85/85 [==============================] - 4s 45ms/step - loss: 1.8820
# Epoch 200/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.8676
# Epoch 201/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.8585
# Epoch 202/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.8517
# Epoch 203/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.8359
# Epoch 204/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.8274
# Epoch 205/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.8190
# Epoch 206/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.8083
# Epoch 207/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.7924
# Epoch 208/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.7823
# Epoch 209/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.7719
# Epoch 210/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.7620
# Epoch 211/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.7475
# Epoch 212/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.7396
# Epoch 213/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.7315
# Epoch 214/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.7224
# Epoch 215/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.7084
# Epoch 216/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.6997
# Epoch 217/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.6869
# Epoch 218/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.6790
# Epoch 219/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.6682
# Epoch 220/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.6585
# Epoch 221/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.6459
# Epoch 222/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.6400
# Epoch 223/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.6282
# Epoch 224/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.6166
# Epoch 225/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.6131
# Epoch 226/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.5981
# Epoch 227/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.5907
# Epoch 228/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.5848
# Epoch 229/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.5730
# Epoch 230/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.5614
# Epoch 231/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.5522
# Epoch 232/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.5414
# Epoch 233/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.5278
# Epoch 234/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.5233
# Epoch 235/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.5128
# Epoch 236/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.5039
# Epoch 237/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.4960
# Epoch 238/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.4838
# Epoch 239/600
# 85/85 [==============================] - 4s 45ms/step - loss: 1.4816
# Epoch 240/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.4671
# Epoch 241/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.4583
# Epoch 242/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.4494
# Epoch 243/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.4383
# Epoch 244/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.4306
# Epoch 245/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.4221
# Epoch 246/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.4125
# Epoch 247/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.4046
# Epoch 248/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.3995
# Epoch 249/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.3892
# Epoch 250/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.3796
# Epoch 251/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.3713
# Epoch 252/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.3617
# Epoch 253/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.3563
# Epoch 254/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.3447
# Epoch 255/600
# 85/85 [==============================] - 4s 45ms/step - loss: 1.3398
# Epoch 256/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.3305
# Epoch 257/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.3205
# Epoch 258/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.3089
# Epoch 259/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.3068
# Epoch 260/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.2966
# Epoch 261/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.2904
# Epoch 262/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.2785
# Epoch 263/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.2710
# Epoch 264/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.2614
# Epoch 265/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.2541
# Epoch 266/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.2500
# Epoch 267/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.2368
# Epoch 268/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.2342
# Epoch 269/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.2216
# Epoch 270/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.2154
# Epoch 271/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.2069
# Epoch 272/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.2001
# Epoch 273/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.1951
# Epoch 274/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.1846
# Epoch 275/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.1775
# Epoch 276/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.1695
# Epoch 277/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.1626
# Epoch 278/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.1563
# Epoch 279/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.1462
# Epoch 280/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.1381
# Epoch 281/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.1332
# Epoch 282/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.1231
# Epoch 283/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.1165
# Epoch 284/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.1076
# Epoch 285/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.1014
# Epoch 286/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.0951
# Epoch 287/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.0878
# Epoch 288/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.0821
# Epoch 289/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.0734
# Epoch 290/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.0673
# Epoch 291/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.0584
# Epoch 292/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.0532
# Epoch 293/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.0455
# Epoch 294/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.0384
# Epoch 295/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.0341
# Epoch 296/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.0225
# Epoch 297/600
# 85/85 [==============================] - 4s 42ms/step - loss: 1.0175
# Epoch 298/600
# 85/85 [==============================] - 4s 43ms/step - loss: 1.0109
# Epoch 299/600
# 85/85 [==============================] - 4s 44ms/step - loss: 1.0036
# Epoch 300/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.9932
# Epoch 301/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.9884
# Epoch 302/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.9855
# Epoch 303/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.9746
# Epoch 304/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.9721
# Epoch 305/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.9597
# Epoch 306/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.9556
# Epoch 307/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.9495
# Epoch 308/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.9462
# Epoch 309/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.9368
# Epoch 310/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.9294
# Epoch 311/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.9262
# Epoch 312/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.9181
# Epoch 313/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.9112
# Epoch 314/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.9037
# Epoch 315/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.9001
# Epoch 316/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.8946
# Epoch 317/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.8847
# Epoch 318/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.8815
# Epoch 319/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.8739
# Epoch 320/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.8680
# Epoch 321/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.8633
# Epoch 322/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.8595
# Epoch 323/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.8516
# Epoch 324/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.8444
# Epoch 325/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.8410
# Epoch 326/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.8333
# Epoch 327/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.8286
# Epoch 328/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.8234
# Epoch 329/600
# 85/85 [==============================] - 4s 45ms/step - loss: 0.8163
# Epoch 330/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.8080
# Epoch 331/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.8065
# Epoch 332/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.7991
# Epoch 333/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.7946
# Epoch 334/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.7906
# Epoch 335/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.7814
# Epoch 336/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.7779
# Epoch 337/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.7701
# Epoch 338/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.7654
# Epoch 339/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.7594
# Epoch 340/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.7545
# Epoch 341/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.7528
# Epoch 342/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.7444
# Epoch 343/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.7412
# Epoch 344/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.7368
# Epoch 345/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.7293
# Epoch 346/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.7227
# Epoch 347/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.7194
# Epoch 348/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.7157
# Epoch 349/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.7098
# Epoch 350/600
# 85/85 [==============================] - 4s 45ms/step - loss: 0.7025
# Epoch 351/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.7008
# Epoch 352/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.6962
# Epoch 353/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6907
# Epoch 354/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.6840
# Epoch 355/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.6787
# Epoch 356/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6757
# Epoch 357/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.6707
# Epoch 358/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.6650
# Epoch 359/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.6611
# Epoch 360/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6559
# Epoch 361/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6545
# Epoch 362/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.6478
# Epoch 363/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.6426
# Epoch 364/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6389
# Epoch 365/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6334
# Epoch 366/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.6315
# Epoch 367/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6244
# Epoch 368/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6207
# Epoch 369/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6155
# Epoch 370/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6122
# Epoch 371/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6082
# Epoch 372/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.6042
# Epoch 373/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.6000
# Epoch 374/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5966
# Epoch 375/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5911
# Epoch 376/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.5885
# Epoch 377/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.5839
# Epoch 378/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5778
# Epoch 379/600
# 85/85 [==============================] - 4s 46ms/step - loss: 0.5745
# Epoch 380/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.5690
# Epoch 381/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.5661
# Epoch 382/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.5611
# Epoch 383/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.5584
# Epoch 384/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5538
# Epoch 385/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5517
# Epoch 386/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.5466
# Epoch 387/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5427
# Epoch 388/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5376
# Epoch 389/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.5357
# Epoch 390/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5314
# Epoch 391/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5279
# Epoch 392/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.5244
# Epoch 393/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5214
# Epoch 394/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5168
# Epoch 395/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5132
# Epoch 396/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.5103
# Epoch 397/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.5059
# Epoch 398/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.5028
# Epoch 399/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4982
# Epoch 400/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4959
# Epoch 401/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4913
# Epoch 402/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4872
# Epoch 403/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4855
# Epoch 404/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4824
# Epoch 405/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4779
# Epoch 406/600
# 85/85 [==============================] - 4s 45ms/step - loss: 0.4745
# Epoch 407/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4726
# Epoch 408/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4680
# Epoch 409/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4636
# Epoch 410/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4619
# Epoch 411/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4587
# Epoch 412/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.4553
# Epoch 413/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4525
# Epoch 414/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4480
# Epoch 415/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4476
# Epoch 416/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4425
# Epoch 417/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4411
# Epoch 418/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4368
# Epoch 419/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4333
# Epoch 420/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4303
# Epoch 421/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4262
# Epoch 422/600
# 85/85 [==============================] - 4s 45ms/step - loss: 0.4232
# Epoch 423/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4210
# Epoch 424/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4196
# Epoch 425/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4137
# Epoch 426/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4124
# Epoch 427/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4092
# Epoch 428/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4053
# Epoch 429/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4014
# Epoch 430/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.3994
# Epoch 431/600
# 85/85 [==============================] - 4s 45ms/step - loss: 0.3973
# Epoch 432/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3941
# Epoch 433/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.3917
# Epoch 434/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.3886
# Epoch 435/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3861
# Epoch 436/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3840
# Epoch 437/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.3814
# Epoch 438/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3785
# Epoch 439/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3773
# Epoch 440/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3721
# Epoch 441/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3704
# Epoch 442/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3672
# Epoch 443/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3635
# Epoch 444/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3629
# Epoch 445/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3605
# Epoch 446/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3583
# Epoch 447/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3540
# Epoch 448/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3515
# Epoch 449/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3502
# Epoch 450/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3454
# Epoch 451/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.3462
# Epoch 452/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3429
# Epoch 453/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3383
# Epoch 454/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3379
# Epoch 455/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3350
# Epoch 456/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3331
# Epoch 457/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3307
# Epoch 458/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.3265
# Epoch 459/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3252
# Epoch 460/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3225
# Epoch 461/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.3189
# Epoch 462/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.3172
# Epoch 463/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3160
# Epoch 464/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3145
# Epoch 465/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3110
# Epoch 466/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3103
# Epoch 467/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3064
# Epoch 468/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3046
# Epoch 469/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3016
# Epoch 470/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3011
# Epoch 471/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2989
# Epoch 472/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2952
# Epoch 473/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2937
# Epoch 474/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2905
# Epoch 475/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2899
# Epoch 476/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2879
# Epoch 477/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2847
# Epoch 478/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2828
# Epoch 479/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2810
# Epoch 480/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2788
# Epoch 481/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2772
# Epoch 482/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2753
# Epoch 483/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2726
# Epoch 484/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2698
# Epoch 485/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2682
# Epoch 486/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2671
# Epoch 487/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2649
# Epoch 488/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2621
# Epoch 489/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2611
# Epoch 490/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2579
# Epoch 491/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2563
# Epoch 492/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2551
# Epoch 493/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2526
# Epoch 494/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2498
# Epoch 495/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2480
# Epoch 496/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2480
# Epoch 497/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2458
# Epoch 498/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2432
# Epoch 499/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2408
# Epoch 500/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2396
# Epoch 501/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2386
# Epoch 502/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2357
# Epoch 503/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2341
# Epoch 504/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2330
# Epoch 505/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2324
# Epoch 506/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2309
# Epoch 507/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2266
# Epoch 508/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2253
# Epoch 509/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2241
# Epoch 510/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2229
# Epoch 511/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2208
# Epoch 512/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2189
# Epoch 513/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2181
# Epoch 514/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2157
# Epoch 515/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2153
# Epoch 516/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2127
# Epoch 517/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2116
# Epoch 518/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2099
# Epoch 519/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2075
# Epoch 520/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2057
# Epoch 521/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2041
# Epoch 522/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2034
# Epoch 523/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2030
# Epoch 524/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2023
# Epoch 525/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1985
# Epoch 526/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1978
# Epoch 527/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1948
# Epoch 528/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1941
# Epoch 529/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1935
# Epoch 530/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.1914
# Epoch 531/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1901
# Epoch 532/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1882
# Epoch 533/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1871
# Epoch 534/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1866
# Epoch 535/600
# 85/85 [==============================] - 4s 45ms/step - loss: 0.1851
# Epoch 536/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1829
# Epoch 537/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1823
# Epoch 538/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.1800
# Epoch 539/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.1790
# Epoch 540/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1784
# Epoch 541/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1759
# Epoch 542/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1753
# Epoch 543/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1731
# Epoch 544/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1722
# Epoch 545/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1714
# Epoch 546/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1703
# Epoch 547/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1684
# Epoch 548/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1673
# Epoch 549/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1666
# Epoch 550/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1647
# Epoch 551/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1630
# Epoch 552/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1630
# Epoch 553/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1609
# Epoch 554/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1604
# Epoch 555/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1589
# Epoch 556/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1576
# Epoch 557/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.1567
# Epoch 558/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1556
# Epoch 559/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1539
# Epoch 560/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1536
# Epoch 561/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1516
# Epoch 562/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1517
# Epoch 563/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1493
# Epoch 564/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1479
# Epoch 565/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1477
# Epoch 566/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1462
# Epoch 567/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1451
# Epoch 568/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1445
# Epoch 569/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1433
# Epoch 570/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1422
# Epoch 571/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1407
# Epoch 572/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1396
# Epoch 573/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1386
# Epoch 574/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.1383
# Epoch 575/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1367
# Epoch 576/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1350
# Epoch 577/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1353
# Epoch 578/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1344
# Epoch 579/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1326
# Epoch 580/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1319
# Epoch 581/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1306
# Epoch 582/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1298
# Epoch 583/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1297
# Epoch 584/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1284
# Epoch 585/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1268
# Epoch 586/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1264
# Epoch 587/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1252
# Epoch 588/600
# 85/85 [==============================] - 4s 44ms/step - loss: 0.1240
# Epoch 589/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1234
# Epoch 590/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1221
# Epoch 591/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1216
# Epoch 592/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1213
# Epoch 593/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1198
# Epoch 594/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1200
# Epoch 595/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1192
# Epoch 596/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1184
# Epoch 597/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1172
# Epoch 598/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1156
# Epoch 599/600
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1149
# Epoch 600/600
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1149

# %% [markdown]
# ## 4. Define Inference Models
#
# **Encoder inference model**: Takes the question as input and outputs LSTM states ( `h` and `c` ).
#
# **Decoder inference model**: Takes in 2 inputs, one are the LSTM states ( Output of encoder model ), second are the answer input seqeunces ( ones not having the `<bos>` tag ). It will output the answers for the question which we fed to the encoder model and its state values.

# %%
def make_inference() -> Tuple[tf.keras.models.Model, tf.keras.models.Model]:
    """
    Constructs separate encoder and decoder models for inference based on a trained Encoder-Decoder model.

    Returns:
        encoder_model (tf.keras.models.Model): A Keras model representing the encoder component for inference.
            This model takes encoder inputs (sequences of tokens) and outputs the encoder states (hidden state
            and cell state) produced by the encoder LSTM layer.

        decoder_model (tf.keras.models.Model): A Keras model representing the decoder component for inference.
            This model takes decoder inputs (sequences of tokens) along with the initial decoder states (hidden
            state and cell state) as inputs and outputs the decoder outputs and updated decoder states.
            It consists of the decoder LSTM layer and the decoder dense layer.
    """
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)

    decoder_state_input_h = tf.keras.layers.Input(shape=(200,), name='Input_Layer_h')
    decoder_state_input_c = tf.keras.layers.Input(shape=(200,), name='Input_Layer_c')
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    decoder_outs, state_h, state_c = decoder_lstm(decoder_embedding, initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_ouputs = decoder_dense(decoder_outs)
    decoder_model = tf.keras.models.Model([decoder_inputs] + decoder_states_inputs, [decoder_ouputs] + decoder_states)

    return encoder_model, decoder_model

# %% [markdown]
# ## 5. Talking with Chatbot

# %% [markdown]
# Convert `str` into tokens with paddings.

# %%
def str_to_tokens(sentence: str) -> List[int]:
    words = sentence.lower()
    words = re.sub('[^a-zA-Z0-9\']', ' ', words)
    words = words.split()
    # tokens_list = [ tokenizer.word_index[word] for word in words ]
    tokens_list = list()
    for word in words:
        if word in tokenizer.word_index:
            tokens_list.append(tokenizer.word_index[word])
        else:
            tokens_list.append(tokenizer.word_index['unk'])
    padded_sequence = preprocessing.sequence.pad_sequences([tokens_list], maxlen=questions_max_len, padding='post')
    return padded_sequence

# %% [markdown]
# 1.    First, we take a question as input and predict the state values using `encoder_model`.
# 2.    We set the state values in the decoder's LSTM.
# 3.    Then, we generate a sequence which contains the `<start>` element.
# 4.    We input this sequence in the `decoder_model`.
# 5.    We replace the `<bos>` element with the element which was predicted by the `decoder_model` and update the state values.
# 6.    We carry out the above steps iteratively till we hit the `<eos>` tag or the maximum answer length.

# %%
encoder_model, decoder_model = make_inference()

input_strs = [
    "What is your name?",
    "How are you feeling today?",
    "What is the weather like outside?",
    "Can you tell me a joke?",
    "How old are you?",
    "What is the capital of France?",
    "How do I bake a cake?",
    "What time is it?",
    "Who is the president of the United States?",
    "What is the meaning of life?"]

for input_str in input_strs:

    # Convert input string to tokens for the encoder
    states_values = encoder_model.predict(str_to_tokens(input_str), verbose=0)

    # Initialize target sequence with 'bos' (beginning of sentence) token
    empty_target_seq = np.zeros((1, 1))
    empty_target_seq[0, 0] = tokenizer.word_index['bos']

    # Initialize variables for translation and stop condition
    stop_condition = False
    decoded_translation = ''

    while not stop_condition:
        # Predict next word using the decoder model
        decoder_outputs, h, c = decoder_model.predict([empty_target_seq] + states_values, verbose=0)

        # Get index of the most probable word and fine the word corresponding to the index
        sampled_word_index = np.argmax(decoder_outputs[0, -1, :])
        sampled_word = None
        for word, index in tokenizer.word_index.items():
            if sampled_word_index == index:
                if word !="eos" and word !="unk":
                    decoded_translation += f" {word}"
                sampled_word = word

        if sampled_word == 'eos' or len(decoded_translation.split()) > answers_max_len:
            stop_condition = True

        # Update target sequence with sampled word index
        empty_target_seq = np.zeros((1, 1))
        empty_target_seq[0, 0] = sampled_word_index

        # Update states for the next iteration
        states_values = [h, c]

    # Print the decoded translation
    print(f"Answer: {decoded_translation}")
# Out:
# Answer:  the world changed overnight unexpectedly
# Answer:  i will be eating lunch
# Answer:  the time in 24 hour format is 20 45
# Answer:  hent tree what kind of the beach tomorrow
# Answer:  is located in the road decreased by dr k r r martin
# Answer:  the capital of the dominican republic is santo domingo
# Answer:  the puppy pattered purposely past the petunias
# Answer:  4
# Answer:  the black research sea and the movie with a lightning strike an entire online common in which was a low rumbling of regular and a wounded distance
# Answer:  the family goes to understand some vibrant

# %%
encoder_model, decoder_model = make_inference()

input_strs = ['Where is Barack Obama born?',
              'What is the capital of Canada?',
              'Who is the Prime Minister of India?']

for input_str in input_strs:

    # Convert input string to tokens for the encoder
    states_values = encoder_model.predict(str_to_tokens(input_str), verbose=0)

    # Initialize target sequence with 'bos' (beginning of sentence) token
    empty_target_seq = np.zeros((1, 1))
    empty_target_seq[0, 0] = tokenizer.word_index['bos']

    # Initialize variables for translation and stop condition
    stop_condition = False
    decoded_translation = ''

    while not stop_condition:
        # Predict next word using the decoder model
        decoder_outputs, h, c = decoder_model.predict([empty_target_seq] + states_values, verbose=0)

        # Get index of the most probable word and fine the word corresponding to the index
        sampled_word_index = np.argmax(decoder_outputs[0, -1, :])
        sampled_word = None
        for word, index in tokenizer.word_index.items():
            if sampled_word_index == index:
                if word !="eos" and word !="unk":
                    decoded_translation += f" {word}"
                sampled_word = word

        if sampled_word == 'eos' or len(decoded_translation.split()) > answers_max_len:
            stop_condition = True

        # Update target sequence with sampled word index
        empty_target_seq = np.zeros((1, 1))
        empty_target_seq[0, 0] = sampled_word_index

        # Update states for the next iteration
        states_values = [h, c]

    # Print the decoded translation
    print(f"Question: {input_str}")
    print(f"Answer: {decoded_translation}\n")
# Out:
# Question: Where is Barack Obama born?
# Answer:  4 is is they're
#
# Question: What is the capital of Canada?
# Answer:  the samsung galaxy s20 has an approximate retail value of 4 would divide by 7 5
#
# Question: Who is the Prime Minister of India?
# Answer:  the sum of the integers is 3 4

# %% [markdown]
# ## 6. Downloading the Model and Tokenizer

# %%
# zip the files and download
import os
import shutil
from google.colab import files
from datetime import datetime

temp_dir = 'output'
files_to_include = [f'model{dataset_name}.keras', f'tokenizer{dataset_name}.pickle']

if not os.path.exists(temp_dir):
    os.makedirs(temp_dir)

try:
    for file in files_to_include:
        shutil.copy(file, temp_dir)
except Exception as e:
    print(f"Error copying files: {e}")

file_name = f"Model{dataset_name}_{datetime.now().strftime('%Y%m%d-%H%M%S')}"
shutil.make_archive(file_name, 'zip', 'output')
files.download(file_name + '.zip')
